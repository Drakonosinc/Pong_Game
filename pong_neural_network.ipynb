# %%
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import numpy as np

# %%
# creados dos variables para almacenar la ruta de los archivos
state_file_path = os.path.join("C:/Users/Cancino/Desktop/codigos de programacion/Python/proyecto/1/final_version/pong data/pong_states.npy")
action_file_path = os.path.join("C:/Users/Cancino/Desktop/codigos de programacion/Python/proyecto/1/final_version/pong data/pong_actions.npy")
#chequeamos si existen
if not os.path.exists(state_file_path):
    print(f"File not found: {state_file_path}")
else:
    print(f"File found: {state_file_path}")

if not os.path.exists(action_file_path):
    print(f"File not found: {action_file_path}")
else:
    print(f"File found: {action_file_path}")

# Cargar los datos si los archivos existen
if os.path.exists(state_file_path) and os.path.exists(action_file_path):
    states = np.load(state_file_path)
    actions = np.load(action_file_path)
#dimensiones de la ventana
WEIGHT,HEIGHT=700,400
# Out:
# File found: C:/Users/Cancino/Desktop/codigos de programacion/Python/proyecto/1/final_version/pong data/pong_states.npy
# File found: C:/Users/Cancino/Desktop/codigos de programacion/Python/proyecto/1/final_version/pong data/pong_actions.npy

# %%
#normalizamos los datos de states
# Normalizar los datos: Dividir las posiciones por el tamaño máximo del campo y las velocidades por sus máximos valores esperados
states[:, 0] = states[:, 0] / HEIGHT  # Normalizar la posición Y del paddle1
states[:, 1] = states[:, 1] / HEIGHT  # Normalizar la posición Y del paddle2
states[:, 2] = states[:, 2] / WEIGHT  # Normalizar la posición X de la pelota1
states[:, 3] = states[:, 3] / HEIGHT  # Normalizar la posición Y de la pelota1
states[:, 4] = states[:, 4] / np.max(np.abs(states[:, 4]))  # Normalizar la velocidad X de la pelota1
states[:, 5] = states[:, 5] / np.max(np.abs(states[:, 5]))  # Normalizar la velocidad Y de la pelota1

# %%
#creamos el modelo de la red neuronal
model = Sequential([
    Dense(128, input_dim=6, activation='relu'),# 14 entradas ya que son los datos almacenados en states
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),# neuronas en medio para un mejor procesamiento
    Dense(512, activation='relu'),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(2, activation='linear')# 2 de salida para indicar si sube o baja
])
#copilamos el modelo
model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# %%
# Entrenar el modelo
model.fit(states, actions, epochs=250, batch_size=64)
model.save('pong_ai_version_2.keras')
# Out:
# Epoch 1/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.3163
# Epoch 2/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0055
# Epoch 3/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0069
# Epoch 4/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0060
# Epoch 5/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0053
# Epoch 6/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0049
# Epoch 7/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0050
# Epoch 8/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0057
# Epoch 9/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0048
# Epoch 10/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0049
# Epoch 11/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0047
# Epoch 12/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0044
# Epoch 13/250
# 213/213 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0054
# Epoch 14/250
# ...
